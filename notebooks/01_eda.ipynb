# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/egfr_raw.csv")
print(df.shape)
df.head()
# Out:
# (13286, 6)
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL5073622  C=CC(=O)N1CC[C@H](Oc2nc(-c3n[nH]c(=O)[nH]3)cc3...
# 1      CHEMBL3353410  C=CC(=O)Nc1cc(Nc2nccc(-c3cn(C)c4ccccc34)n2)c(O...
# 2        CHEMBL63786                  Brc1cccc(Nc2ncnc3cc4ccccc4cc23)c1
# 3        CHEMBL53711                 CN(C)c1cc2c(Nc3cccc(Br)c3)ncnc2cn1
# 4        CHEMBL35820                CCOc1cc2ncnc(Nc3cccc(Br)c3)c2cc1OCC
#
#    standard_value standard_units    pchembl assay_chembl_id
# 0    5.012000e-09             nM  17.299989   CHEMBL5031734
# 1    2.000000e-03             nM  11.698970   CHEMBL4721173
# 2    3.000000e-03             nM  11.522879    CHEMBL683040
# 3    6.000000e-03             nM  11.221849    CHEMBL674648
# 4    6.000000e-03             nM  11.221849    CHEMBL680017

# %%
df.describe()
# Out:
#        standard_value       pchembl
# count    1.328600e+04  13286.000000
# mean     1.639722e+04      6.802492
# std      2.918210e+05      1.506446
# min      5.012000e-09      1.602060
# 25%      1.044000e+01      5.606427
# 50%      1.000000e+02      7.000000
# 75%      2.475000e+03      7.981302
# max      2.500000e+07     17.299989

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(df["pchembl"], bins=50, color="steelblue", edgecolor="white")
plt.xlabel("pChEMBL")
plt.ylabel("Count")
plt.title("pChEMBL Distribution")

plt.subplot(1, 2, 2)
plt.hist(df["standard_value"], bins=50, color="salmon", edgecolor="white")
plt.xlabel("IC50 (nM)")
plt.ylabel("Count")
plt.title("IC50 Distribution (raw)")

plt.tight_layout()
plt.savefig("../results/pchembl_distribution.png", dpi=150)
plt.show()

# %%
df["smiles_length"] = df["canonical_smiles"].str.len()

plt.figure(figsize=(8, 4))
plt.hist(df["smiles_length"], bins=50, color="mediumpurple", edgecolor="white")
plt.xlabel("SMILES Length")
plt.ylabel("Count")
plt.title("Molecular Complexity Distribution")
plt.savefig("../results/smiles_length_distribution.png", dpi=150)
plt.show()

print(f"Mean SMILES length: {df['smiles_length'].mean():.1f}")
print(f"Max SMILES length:  {df['smiles_length'].max()}")
# Out:
# Mean SMILES length: 58.6
# Max SMILES length:  248
